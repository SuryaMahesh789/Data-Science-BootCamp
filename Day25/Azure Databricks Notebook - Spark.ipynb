# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=3184845613749777#setting/sparkui/0828-035735-jkngkp57/driver-6070682628050721116">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://10.139.64.6:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
data = spark.read.csv('file:/Workspace/Users/d-user11@heu.ai/Educational_Universities_data.csv', header=True, inferSchema=True)

# %%
data.show()
# Out:
# +---------+--------------------+--------------------+------------------+----------------------+-----------+----------------------------+------------+----------+----------------+------------+----------+------------------+-------+----------+----------------+------------+------+-------+
# |  Country|               State|     University Name|Type of University|Tie Up with University|     School|Technologies/Courses Offered|Course Types|Unplaced %|Corporate Tie Up|Job Offering|Internship|Marketing Strategy|Costing|Hackathons|Services Offered|Scholarships|  Tier|Ranking|
# +---------+--------------------+--------------------+------------------+----------------------+-----------+----------------------------+------------+----------+----------------+------------+----------+------------------+-------+----------+----------------+------------+------+-------+
# ...

# %%
data.toPandas()
# Out:
#        Country                         State  ...    Tier Ranking
# 0    Australia  Australian Capital Territory  ...  Tier 3      24
# 1    Australia  Australian Capital Territory  ...  Tier 1     336
# 2    Australia               New South Wales  ...  Tier 1      19
# 3    Australia               New South Wales  ...  Tier 1     429
# 4    Australia               New South Wales  ...  Tier 2     132
# ..         ...                           ...  ...     ...     ...
# 242     Jordan                         Zarqa  ...  Tier 3     270
# 243     Jordan                        Madaba  ...  Tier 3     869
# 244     Jordan                        Ajloun  ...  Tier 1     463
# 245     Jordan                        Mafraq  ...  Tier 1     650
# 246     Jordan                         Karak  ...  Tier 3     360
#
# [247 rows x 19 columns]

# %%
data.toPandas().head()
# Out:
#      Country                         State  ...    Tier Ranking
# 0  Australia  Australian Capital Territory  ...  Tier 3      24
# 1  Australia  Australian Capital Territory  ...  Tier 1     336
# 2  Australia               New South Wales  ...  Tier 1      19
# 3  Australia               New South Wales  ...  Tier 1     429
# 4  Australia               New South Wales  ...  Tier 2     132
#
# [5 rows x 19 columns]

# %% [markdown]
# #### We are done with Importing data into notebook and perform the spark commands here
# #### Let's see, How to import data from containers to notebook
# #### Create Storage Account in Azure, Create Container and upload data into the container
# #### Get the access key from the access key's from the storage account
#
# - suryasgaccount - storage account in azure
# - input container - container inside the storage account for importing data
# - output container - container inside the storage account for exporting data
# - accesskey - bX9GTIJkZJZjoO4zDo0c4FUc+FH50ryprwIKLJgHSZ9pzrBwISxIjbjLFufqpMC4AyaOacKi7D5g+ASt91l7rQ==

# %%
spark.conf.set( "fs.azure.account.key.suryasgaccount.blob.core.windows.net", "bX9GTIJkZJZjoO4zDo0c4FUc+FH50ryprwIKLJgHSZ9pzrBwISxIjbjLFufqpMC4AyaOacKi7D5g+ASt91l7rQ==" )

# %%
# IMPORTING DATA:
df=spark.read.format("csv").option("header","true").load("wasbs://inputcontainer@suryasgaccount.blob.core.windows.net/Educational_Universities_data.csv")

# %%
df.show()
# Out:
# +---------+--------------------+--------------------+------------------+----------------------+-----------+----------------------------+------------+----------+----------------+------------+----------+------------------+-------+----------+----------------+------------+------+-------+
# |  Country|               State|     University Name|Type of University|Tie Up with University|     School|Technologies/Courses Offered|Course Types|Unplaced %|Corporate Tie Up|Job Offering|Internship|Marketing Strategy|Costing|Hackathons|Services Offered|Scholarships|  Tier|Ranking|
# +---------+--------------------+--------------------+------------------+----------------------+-----------+----------------------------+------------+----------+----------------+------------+----------+------------------+-------+----------+----------------+------------+------+-------+
# ...

# %%
df.toPandas()
# Out:
#        Country                         State  ...    Tier Ranking
# 0    Australia  Australian Capital Territory  ...  Tier 3      24
# 1    Australia  Australian Capital Territory  ...  Tier 1     336
# 2    Australia               New South Wales  ...  Tier 1      19
# 3    Australia               New South Wales  ...  Tier 1     429
# 4    Australia               New South Wales  ...  Tier 2     132
# ..         ...                           ...  ...     ...     ...
# 242     Jordan                         Zarqa  ...  Tier 3     270
# 243     Jordan                        Madaba  ...  Tier 3     869
# 244     Jordan                        Ajloun  ...  Tier 1     463
# 245     Jordan                        Mafraq  ...  Tier 1     650
# 246     Jordan                         Karak  ...  Tier 3     360
#
# [247 rows x 19 columns]

# %%
data=df.toPandas()

# %%
data
# Out:
#        Country                         State  ...    Tier Ranking
# 0    Australia  Australian Capital Territory  ...  Tier 3      24
# 1    Australia  Australian Capital Territory  ...  Tier 1     336
# 2    Australia               New South Wales  ...  Tier 1      19
# 3    Australia               New South Wales  ...  Tier 1     429
# 4    Australia               New South Wales  ...  Tier 2     132
# ..         ...                           ...  ...     ...     ...
# 242     Jordan                         Zarqa  ...  Tier 3     270
# 243     Jordan                        Madaba  ...  Tier 3     869
# 244     Jordan                        Ajloun  ...  Tier 1     463
# 245     Jordan                        Mafraq  ...  Tier 1     650
# 246     Jordan                         Karak  ...  Tier 3     360
#
# [247 rows x 19 columns]

# %%
data.head()
# Out:
#      Country                         State  ...    Tier Ranking
# 0  Australia  Australian Capital Territory  ...  Tier 3      24
# 1  Australia  Australian Capital Territory  ...  Tier 1     336
# 2  Australia               New South Wales  ...  Tier 1      19
# 3  Australia               New South Wales  ...  Tier 1     429
# 4  Australia               New South Wales  ...  Tier 2     132
#
# [5 rows x 19 columns]

# %%
data.tail()
# Out:
#     Country   State                University Name  ... Scholarships    Tier Ranking
# 242  Jordan   Zarqa    Al-Zarqa Private University  ...           No  Tier 3     270
# 243  Jordan  Madaba  American University of Madaba  ...           No  Tier 3     869
# 244  Jordan  Ajloun     Ajloun National University  ...          Yes  Tier 1     463
# 245  Jordan  Mafraq          Al al-Bayt University  ...           No  Tier 1     650
# 246  Jordan   Karak               Mutah University  ...           No  Tier 3     360
#
# [5 rows x 19 columns]

# %%
data.describe
# Out:
# <bound method NDFrame.describe of        Country                         State  ...    Tier Ranking
# 0    Australia  Australian Capital Territory  ...  Tier 3      24
# 1    Australia  Australian Capital Territory  ...  Tier 1     336
# 2    Australia               New South Wales  ...  Tier 1      19
# 3    Australia               New South Wales  ...  Tier 1     429
# 4    Australia               New South Wales  ...  Tier 2     132
# ..         ...                           ...  ...     ...     ...
# 242     Jordan                         Zarqa  ...  Tier 3     270
# 243     Jordan                        Madaba  ...  Tier 3     869
# 244     Jordan                        Ajloun  ...  Tier 1     463
# 245     Jordan                        Mafraq  ...  Tier 1     650
# 246     Jordan                         Karak  ...  Tier 3     360
#
# [247 rows x 19 columns]>

# %%
df.show()
# Out:
# +---------+--------------------+--------------------+------------------+----------------------+-----------+----------------------------+------------+----------+----------------+------------+----------+------------------+-------+----------+----------------+------------+------+-------+
# |  Country|               State|     University Name|Type of University|Tie Up with University|     School|Technologies/Courses Offered|Course Types|Unplaced %|Corporate Tie Up|Job Offering|Internship|Marketing Strategy|Costing|Hackathons|Services Offered|Scholarships|  Tier|Ranking|
# +---------+--------------------+--------------------+------------------+----------------------+-----------+----------------------------+------------+----------+----------------+------------+----------+------------------+-------+----------+----------------+------------+------+-------+
# ...

# %%
df.show(5)
# Out:
# +---------+--------------------+--------------------+------------------+----------------------+-----------+----------------------------+------------+----------+----------------+------------+----------+------------------+-------+----------+----------------+------------+------+-------+
# |  Country|               State|     University Name|Type of University|Tie Up with University|     School|Technologies/Courses Offered|Course Types|Unplaced %|Corporate Tie Up|Job Offering|Internship|Marketing Strategy|Costing|Hackathons|Services Offered|Scholarships|  Tier|Ranking|
# +---------+--------------------+--------------------+------------------+----------------------+-----------+----------------------------+------------+----------+----------------+------------+----------+------------------+-------+----------+----------------+------------+------+-------+
# ...

# %%
data.head(10)
# Out:
#      Country                         State  ...    Tier Ranking
# 0  Australia  Australian Capital Territory  ...  Tier 3      24
# 1  Australia  Australian Capital Territory  ...  Tier 1     336
# 2  Australia               New South Wales  ...  Tier 1      19
# 3  Australia               New South Wales  ...  Tier 1     429
# 4  Australia               New South Wales  ...  Tier 2     132
# 5  Australia               New South Wales  ...  Tier 1      56
# 6  Australia               New South Wales  ...  Tier 1     648
# 7  Australia               New South Wales  ...  Tier 1     940
# 8  Australia               New South Wales  ...  Tier 1       9
# 9  Australia               New South Wales  ...  Tier 1     650
#
# [10 rows x 19 columns]

# %% [markdown]
# #### Let's Export the data frame to output container of the storage account as results.csv

# %%
df.write.format("csv").option("header", "true").save("wasbs://outputcontainer@suryasgaccount.blob.core.windows.net/outputcontainer/data.csv")

# %%
df.show()
# Out:
# +---------+--------------------+--------------------+------------------+----------------------+-----------+----------------------------+------------+----------+----------------+------------+----------+------------------+-------+----------+----------------+------------+------+-------+
# |  Country|               State|     University Name|Type of University|Tie Up with University|     School|Technologies/Courses Offered|Course Types|Unplaced %|Corporate Tie Up|Job Offering|Internship|Marketing Strategy|Costing|Hackathons|Services Offered|Scholarships|  Tier|Ranking|
# +---------+--------------------+--------------------+------------------+----------------------+-----------+----------------------------+------------+----------+----------------+------------+----------+------------------+-------+----------+----------------+------------+------+-------+
# ...

# %%
df.show(5)
# Out:
# +---------+--------------------+--------------------+------------------+----------------------+-----------+----------------------------+------------+----------+----------------+------------+----------+------------------+-------+----------+----------------+------------+------+-------+
# |  Country|               State|     University Name|Type of University|Tie Up with University|     School|Technologies/Courses Offered|Course Types|Unplaced %|Corporate Tie Up|Job Offering|Internship|Marketing Strategy|Costing|Hackathons|Services Offered|Scholarships|  Tier|Ranking|
# +---------+--------------------+--------------------+------------------+----------------------+-----------+----------------------------+------------+----------+----------------+------------+----------+------------------+-------+----------+----------------+------------+------+-------+
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- Country: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- University Name: string (nullable = true)
#  |-- Type of University: string (nullable = true)
#  |-- Tie Up with University: string (nullable = true)
#  |-- School: string (nullable = true)
#  |-- Technologies/Courses Offered: string (nullable = true)
#  |-- Course Types: string (nullable = true)
#  |-- Unplaced %: string (nullable = true)
#  |-- Corporate Tie Up: string (nullable = true)
#  |-- Job Offering: string (nullable = true)
#  |-- Internship: string (nullable = true)
#  |-- Marketing Strategy: string (nullable = true)
#  |-- Costing: string (nullable = true)
#  |-- Hackathons: string (nullable = true)
#  |-- Services Offered: string (nullable = true)
#  |-- Scholarships: string (nullable = true)
#  |-- Tier: string (nullable = true)
#  |-- Ranking: string (nullable = true)

# %%
df.describe().show()
# Out:
# +-------+---------+-----------+--------------------+------------------+----------------------+-------+----------------------------+------------+-----------------+----------------+------------+----------+------------------+-------+----------+----------------+------------+------+------------------+
# |summary|  Country|      State|     University Name|Type of University|Tie Up with University| School|Technologies/Courses Offered|Course Types|       Unplaced %|Corporate Tie Up|Job Offering|Internship|Marketing Strategy|Costing|Hackathons|Services Offered|Scholarships|  Tier|           Ranking|
# +-------+---------+-----------+--------------------+------------------+----------------------+-------+----------------------------+------------+-----------------+----------------+------------+----------+------------------+-------+----------+----------------+------------+------+------------------+
# ...

# %%
df.select('Country').show()
# Out:
# +---------+
# |  Country|
# +---------+
# |Australia|
# |Australia|
# |Australia|
# |Australia|
# |Australia|
# |Australia|
# |Australia|
# |Australia|
# |Australia|
# |Australia|
# |Australia|
# |Australia|
# |Australia|
# |Australia|
# |Australia|
# |Australia|
# |Australia|
# |Australia|
# |Australia|
# |Australia|
# +---------+
# only showing top 20 rows

# %%
df.select(['Country','State']).show()
# Out:
# +---------+--------------------+
# |  Country|               State|
# +---------+--------------------+
# |Australia|Australian Capita...|
# |Australia|Australian Capita...|
# |Australia|     New South Wales|
# |Australia|     New South Wales|
# |Australia|     New South Wales|
# |Australia|     New South Wales|
# |Australia|     New South Wales|
# |Australia|     New South Wales|
# |Australia|     New South Wales|
# |Australia|     New South Wales|
# |Australia|     New South Wales|
# |Australia|            Victoria|
# |Australia|            Victoria|
# |Australia|            Victoria|
# |Australia|            Victoria|
# |Australia|            Victoria|
# |Australia|            Victoria|
# |Australia|          Queensland|
# |Australia|          Queensland|
# |Australia|          Queensland|
# +---------+--------------------+
# only showing top 20 rows

# %% [markdown]
# #### 3.Visualizing data with Databricks notebooks

# %%
# Convert Spark DataFrame to Pandas DataFrame for easier plotting
pdf = df.toPandas()
pdf
# Out:
#        Country                         State  ...    Tier Ranking
# 0    Australia  Australian Capital Territory  ...  Tier 3      24
# 1    Australia  Australian Capital Territory  ...  Tier 1     336
# 2    Australia               New South Wales  ...  Tier 1      19
# 3    Australia               New South Wales  ...  Tier 1     429
# 4    Australia               New South Wales  ...  Tier 2     132
# ..         ...                           ...  ...     ...     ...
# 242     Jordan                         Zarqa  ...  Tier 3     270
# 243     Jordan                        Madaba  ...  Tier 3     869
# 244     Jordan                        Ajloun  ...  Tier 1     463
# 245     Jordan                        Mafraq  ...  Tier 1     650
# 246     Jordan                         Karak  ...  Tier 3     360
#
# [247 rows x 19 columns]

# %%
import matplotlib.pyplot as plt

# Plot a simple bar chart
plt.figure(figsize=(10, 6))
pdf['Country'].value_counts().plot(kind='bar')
plt.title("Bar Chart Example")
plt.show()

# %% [markdown]
# #### 4.Data Engineering with Databricks
# - Extract, Load, Transform (ELT): Data is ingested from various sources into a data lake or storage in its raw form - and later transformed as needed.-

# %%
pdf['Ranking']
# Out:
# 0       24
# 1      336
# 2       19
# 3      429
# 4      132
#       ...
# 242    270
# 243    869
# 244    463
# 245    650
# 246    360
# Name: Ranking, Length: 247, dtype: object

# %%
df.select('Ranking').show()
# Out:
# +-------+
# |Ranking|
# +-------+
# |     24|
# |    336|
# |     19|
# |    429|
# |    132|
# |     56|
# |    648|
# |    940|
# |      9|
# |    650|
# |    868|
# |    722|
# |    505|
# |    240|
# |    957|
# |    250|
# |     43|
# |    202|
# |    879|
# |    480|
# +-------+
# only showing top 20 rows

# %%
filtered_df=df.filter(df['Ranking']>500)
filtered_df
# Out:
# DataFrame[Country: string, State: string, University Name: string, Type of University: string, Tie Up with University: string, School: string, Technologies/Courses Offered: string, Course Types: string, Unplaced %: string, Corporate Tie Up: string, Job Offering: string, Internship: string, Marketing Strategy: string, Costing: string, Hackathons: string, Services Offered: string, Scholarships: string, Tier: string, Ranking: string]

# %%
filtered_df.toPandas()
# Out:
#        Country            State  ...    Tier Ranking
# 0    Australia  New South Wales  ...  Tier 1     648
# 1    Australia  New South Wales  ...  Tier 1     940
# 2    Australia  New South Wales  ...  Tier 1     650
# 3    Australia  New South Wales  ...  Tier 1     868
# 4    Australia         Victoria  ...  Tier 1     722
# ..         ...              ...  ...     ...     ...
# 125     Jordan            Amman  ...  Tier 2     824
# 126     Jordan            Irbid  ...  Tier 3     641
# 127     Jordan            Aqaba  ...  Tier 1     987
# 128     Jordan           Madaba  ...  Tier 3     869
# 129     Jordan           Mafraq  ...  Tier 1     650
#
# [130 rows x 19 columns]

# %%
# Select specific columns
transformed_df = filtered_df.select("Technologies/Courses Offered", "University Name", "Costing")

# %%
transformed_df
# Out:
# DataFrame[Technologies/Courses Offered: string, University Name: string, Costing: string]

# %%
transformed_df.toPandas()
# Out:
#     Technologies/Courses Offered  ... Costing
# 0                 Cyber Security  ...  $34490
# 1                   Data Science  ...  $32846
# 2                            IoT  ...  $28211
# 3                             ML  ...  $36941
# 4                 Cyber Security  ...  $14584
# ..                           ...  ...     ...
# 125                           ML  ...  $15722
# 126                           AI  ...  $19912
# 127                           AI  ...  $36370
# 128                           AI  ...  $28886
# 129                           AI  ...  $22407
#
# [130 rows x 3 columns]

# %%
#### Export the transformed data to output container of storage account

# %%
# Save transformed data back to Blob Storage or Delta Lake for further use
transformed_df.write.format("csv").option("header", "true").save("wasbs://outputcontainer@suryasgaccount.blob.core.windows.net/transformed_data.csv")

# %%
# Save filtered data back to Blob Storage or Delta Lake for further use
filtered_df.write.format("csv").option("header", "true").save("wasbs://outputcontainer@suryasgaccount.blob.core.windows.net/filtered_data.csv")

# %%
# Save transformed data back to Blob Storage or Delta Lake for further use
transformed_df.write.format("csv").option("header", "true").save("wasbs://outputcontainer@suryasgaccount.blob.core.windows.net/transformed_data2.csv")

# %% [markdown]
# #### Let's say you have a DataFrame transformed_df that you need to use in several different operations: python
# #### Copy code
# #### Cache the DataFrame for quicker access in future operations
# #### transformed_df.cache()

# %%
transformed_df.cache()
# Out:
# DataFrame[Technologies/Courses Offered: string, University Name: string, Costing: string]

# %%
result1 = transformed_df.filter("country = 'USA'")
result2 = transformed_df.groupBy("Costing").count()

# %%
# Without caching: Every time transformed_df is used, Databricks would reload or recalculate the data.
# With caching: After the first operation, transformed_df is stored in memory, so subsequent operations are much faster.

# %% [markdown]
# #### 5.Data ingestion and integration
# - Basic data ingestion (reading from storage), integration (joining two datasets), and exporting the integrated data back to the storage

# %%
# Step 1: Ingest Data
# Reading data from Blob Storage
df1 = spark.read.format("csv").option("header", "true").load("wasbs://inputcontainer@suryasgaccount.blob.core.windows.net/Educational_Universities_data.csv")
df2 = spark.read.format("csv").option("header", "true").load("wasbs://inputcontainer@suryasgaccount.blob.core.windows.net/Educational_Institutions.csv")

# %%
df1.toPandas()
# Out:
#        Country                         State  ...    Tier Ranking
# 0    Australia  Australian Capital Territory  ...  Tier 3      24
# 1    Australia  Australian Capital Territory  ...  Tier 1     336
# 2    Australia               New South Wales  ...  Tier 1      19
# 3    Australia               New South Wales  ...  Tier 1     429
# 4    Australia               New South Wales  ...  Tier 2     132
# ..         ...                           ...  ...     ...     ...
# 242     Jordan                         Zarqa  ...  Tier 3     270
# 243     Jordan                        Madaba  ...  Tier 3     869
# 244     Jordan                        Ajloun  ...  Tier 1     463
# 245     Jordan                        Mafraq  ...  Tier 1     650
# 246     Jordan                         Karak  ...  Tier 3     360
#
# [247 rows x 19 columns]

# %%
df2.toPandas()
# Out:
#             Country               State  ...    Tier Ranking
# 0              Iran             Isfahan  ...  Tier 2      58
# 1         Australia     South Australia  ...  Tier 1      21
# 2      Saudi Arabia              Riyadh  ...  Tier 1      66
# 3               UAE           Abu Dhabi  ...  Tier 1       3
# 4         Australia  Northern Territory  ...  Tier 1      37
# ...             ...                 ...  ...     ...     ...
# 99995          Iran              Tehran  ...  Tier 2      38
# 99996          Iran             Mashhad  ...  Tier 2      56
# 99997        Turkey               Izmir  ...  Tier 1      34
# 99998           UAE               Dubai  ...  Tier 2      89
# 99999          Iran             Mashhad  ...  Tier 2      98
#
# [100000 rows x 19 columns]

# %%
# Step 2: Integrate Data
# Joining the two DataFrames on a common column, say "id"
joined_df = df1.join(df2, df1["State"] == df2["State"], "inner")

# %%
joined_df.toPandas()
# Out:
#              Country               State  ...    Tier Ranking
# 0          Australia     South Australia  ...  Tier 1      21
# 1       Saudi Arabia              Riyadh  ...  Tier 1      66
# 2                UAE           Abu Dhabi  ...  Tier 1       3
# 3          Australia  Northern Territory  ...  Tier 1      37
# 4             Kuwait         Kuwait City  ...  Tier 2      20
# ...              ...                 ...  ...     ...     ...
# 350353        Kuwait         Kuwait City  ...  Tier 1      87
# 350354        Kuwait         Kuwait City  ...  Tier 1      82
# 350355        Kuwait         Kuwait City  ...  Tier 1      31
# 350356        Kuwait         Kuwait City  ...  Tier 2      98
# 350357        Kuwait         Kuwait City  ...  Tier 1      96
#
# [350358 rows x 38 columns]

# %%
# Step 3: Export the Integrated Data
# Writing the integrated data back to Blob Storage as a CSV
joined_df.write.format("csv").option("header", "true").save("wasbs://outputcontainer@suryasgaccount.blob.core.windows.net/integrated_data.csv")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-1881339545311304>, line 3
#       1 # Step 3: Export the Integrated Data
#       2 # Writing the integrated data back to Blob Storage as a CSV
# ----> 3 joined_df.write.format("csv").option("header", "true").save("wasbs://outputcontainer@suryasgaccount.blob.core.windows.net/integrated_data.csv")
#
# File /databricks/spark/python/pyspark/instrumentation_utils.py:47, in _wrap_function.<locals>.wrapper(*args, **kwargs)
#      45 start = time.perf_counter()
#      46 try:
# ---> 47     res = func(*args, **kwargs)
#      48     logger.log_success(
#      49         module_name, class_name, function_name, time.perf_counter() - start, signature
#      50     )
#      51     return res
#
# File /databricks/spark/python/pyspark/sql/readwriter.py:1718, in DataFrameWriter.save(self, path, format, mode, partitionBy, **options)
# ...

# %%
# 6.Data cleaning and pre-processing
# Drop Missing Values:
# Remove rows with any missing (null) values.
df_clean = df.dropna()

# %%
df_clean
# Out:
# DataFrame[Country: string, State: string, University Name: string, Type of University: string, Tie Up with University: string, School: string, Technologies/Courses Offered: string, Course Types: string, Unplaced %: string, Corporate Tie Up: string, Job Offering: string, Internship: string, Marketing Strategy: string, Costing: string, Hackathons: string, Services Offered: string, Scholarships: string, Tier: string, Ranking: string]

# %%
# Remove Duplicates:
# Remove duplicate rows.
df_clean = df_clean.dropDuplicates()
df_clean
# Out:
# DataFrame[Country: string, State: string, University Name: string, Type of University: string, Tie Up with University: string, School: string, Technologies/Courses Offered: string, Course Types: string, Unplaced %: string, Corporate Tie Up: string, Job Offering: string, Internship: string, Marketing Strategy: string, Costing: string, Hackathons: string, Services Offered: string, Scholarships: string, Tier: string, Ranking: string]

# %%
# Handle Missing Values (Alternative to Dropping):
# Fill missing values in a specific column, say city, with a default value "Unknown".
df_clean = df_clean.fillna({"Country": "Unknown"})
df_clean
# Out:
# DataFrame[Country: string, State: string, University Name: string, Type of University: string, Tie Up with University: string, School: string, Technologies/Courses Offered: string, Course Types: string, Unplaced %: string, Corporate Tie Up: string, Job Offering: string, Internship: string, Marketing Strategy: string, Costing: string, Hackathons: string, Services Offered: string, Scholarships: string, Tier: string, Ranking: string]
